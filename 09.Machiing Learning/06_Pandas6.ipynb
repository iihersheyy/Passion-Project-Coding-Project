# %%
import pandas as pd
df = pd.read_csv('/content/sample_data/california_housing_test.csv')

df.head(3)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0

# %% [markdown]
# ** More Pandas functions to explore **

# %%
df = df.drop(index=1, axis=1)  # Removing 0th row
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# 5       -119.56     36.51                37.0       1018.0           213.0
# 6       -121.43     38.63                43.0       1009.0           225.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# **Keys of DataFrame**

# %%
df.keys()
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %% [markdown]
# **Shape of DataFrame**

# %%
df.shape    # Returns number of rows and columns in the df
# Out:
# (2998, 9)

# %% [markdown]
# **Unique values in the df**

# %%
df['longitude'].unique()
# Out:
# array([-117.81, -118.36, -119.67, -119.56, -121.43, -120.65, -122.84,
#        -118.02, -118.24, -119.12, -121.93, -117.03, -117.97, -117.99,
#        -120.81, -121.2 , -118.88, -122.59, -122.15, -121.37, -118.16,
#        -122.2 , -117.28, -118.03, -122.42, -118.39, -118.45, -118.48,
#        -119.35, -118.3 , -121.13, -118.08, -118.32, -118.11, -122.53,
#        -118.05, -119.01, -119.32, -116.92, -118.06, -117.27, -118.23,
#        -117.24, -121.91, -118.29, -121.35, -120.99, -119.42, -122.21,
#        -118.17, -117.9 , -121.42, -118.77, -121.82, -122.29, -121.78,
#        -118.41, -121.67, -118.  , -117.22, -121.08, -117.53, -117.46,
#        -121.92, -118.2 , -122.05, -123.79, -120.79, -121.89, -118.43,
#        -118.75, -122.47, -120.69, -118.28, -118.44, -121.99, -121.02,
#        -119.85, -123.52, -122.4 , -118.13, -122.  , -117.5 , -122.22,
#        -119.82, -120.21, -120.97, -121.19, -122.23, -121.31, -117.25,
# ...

# %% [markdown]
# **Grouping the origin and get the sum**

# %%
df['longitude'].value_counts()
# Out:
# -118.26    26
# -118.21    26
# -118.28    25
# -118.29    25
# -118.27    25
#            ..
# -120.33     1
# -119.00     1
# -119.08     1
# -114.61     1
# -119.86     1
# Name: longitude, Length: 607, dtype: int64
